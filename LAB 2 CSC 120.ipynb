# %%
a=3
b=5
c=a+b
print(a,"+",b,"=",c)


a=int(input("Enter first number"))
b=int(input("enter second number")) 
c=a+b
print(a ,'+',b,"=",c)
# Out:
# 3 + 5 = 8
# Enter first number1
# enter second number2
# 1 + 2 = 3
